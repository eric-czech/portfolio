# %%
from pbn import operations as ops
from pbn import suite as pbn
from matplotlib import pyplot as plt
import matplotlib.image as matimg
# %matplotlib inline

# %%
import matplotlib.image as matimg
img = matimg.imread('/Users/eczech/Downloads/google.png')
plt.imshow(img)

# %%
clusters, img_color_cluster, img_spatial_cluster, img_pbn, img_sol = pbn.get_pbn(img, max_colors=50, alpha=.5)

# %%
print 'Number of color clusters = ', len(clusters)
# Out:
# Number of color clusters =  16

# %%
plt.imshow(img_color_cluster)

# %%
plt.imshow(img_spatial_cluster)

# %%
plt.imshow(img_sol)

# %%
plt.imshow(img_pbn)

# %%
matimg.imsave('/tmp/pbn.png', img_sol)
