# %% [markdown]
# # Weighted Linear Regression

# %%
# %run -m ipy_startup
# %matplotlib inline
from scipy.stats import norm

# %%
# Generate random data to model
np.random.seed(1)
n, n_var = 100000, 10
positive_only = False
#n, n_class, n_var = 10000, 4, 5

# Generate per-sample variance
y_variance = .05 + 100 * np.random.rand(n)

X = np.random.randn(n, n_var)

b_act = np.random.randn(n_var)
b_int = -.3

ym = b_int + np.dot(X, b_act)

y = norm.rvs(ym, np.sqrt(y_variance))
if positive_only:
    y = np.exp(y)

X.shape, y.shape
# Out:
# ((100000, 10), (100000,))

# %%
pd.Series(y_variance).describe()
# Out:
# count    100000.000000
# mean         49.971911
# std          28.936320
# min           0.051037
# 25%          24.758765
# 50%          50.034988
# 75%          75.027099
# max         100.049028
# dtype: float64

# %%
pd.Series(y).describe()
# Out:
# count    100000.000000
# mean         -0.363414
# std           7.746547
# min         -42.206046
# 25%          -5.119224
# 50%          -0.359733
# 75%           4.366119
# max          37.984447
# dtype: float64

# %%
from ml.scipy import optimize, models
from ml.sklearn.preprocessing import MeanScaler

param_names = ['X{}'.format(i) for i in range(n_var)]


model = (
    models.ScipyLinearRegressionModelBuilder()
    .add_linear_params(param_names)
    .add_intercept()
    .add_constraints(constraints)
    .build()
)

# %%
# %%time
from sklearn.linear_model import LinearRegression

fit_w = 1/y_variance

# Weight scaling doesn't seem to matter except when it produces very small / large values
# - dividing by the mean seems to be a good practical method
fit_w_scaled = (fit_w / fit_w.mean())

est_wt = optimize.ScipyRegressor(model, analytical_gradients=True, monitor_gradient=True, raise_on_failure=False)
est_wt.fit(X, y, sample_weight=fit_w)

est_wtscaled = optimize.ScipyRegressor(model, analytical_gradients=True, monitor_gradient=True, raise_on_failure=False)
est_wtscaled.fit(X, y, sample_weight=fit_w_scaled)

est_wt1 = optimize.ScipyRegressor(model, analytical_gradients=True, monitor_gradient=True, raise_on_failure=False)
est_wt1.fit(X, y, sample_weight=np.ones(len(y)))

est_nowt = optimize.ScipyRegressor(model, analytical_gradients=True, monitor_gradient=True, raise_on_failure=False)
est_nowt.fit(X, y)

est_skl = LinearRegression().fit(X, y)
est_wtskl = LinearRegression().fit(X, y, 1/y_variance)
# Out:
# CPU times: user 1.67 s, sys: 169 ms, total: 1.84 s
# Wall time: 498 ms

# %%
from sklearn.linear_model import LinearRegression
from collections import OrderedDict

df_coef = pd.DataFrame({
    'est_sklearn': est_skl.coef_,
    'est_wtsklearn': est_wtskl.coef_,
    'est_wt': est_wt.inference()['linear'].values,
    'est_wtscaled': est_wtscaled.inference()['linear'].values,
    'est_ones': est_wt1.inference()['linear'].values,
    'est_nowt': est_nowt.inference()['linear'].values
}, index=est_nowt.inference()['linear'].index)

df_int = pd.DataFrame({
    'est_sklearn': est_skl.intercept_,
    'est_wtsklearn': est_wtskl.intercept_,
    'est_wt': est_wt.inference()['intercept'].values,
    'est_wtscaled': est_wtscaled.inference()['intercept'].values,
    'est_ones': est_wt1.inference()['intercept'].values,
    'est_nowt': est_nowt.inference()['intercept'].values
}, index=est_nowt.inference()['intercept'].index)

df = pd.concat([df_coef, df_int])
df[df.columns.sort_values()].style.bar(axis=1)
# Out:
# <style  type="text/css" >
#     #T_b399249a_b82a_11e7_a421_60f81db72a82row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#         }    #T_b399249a_b82a_11e7_a421_60f81db72a82row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#         }    #T_b399249a_b82a_11e7_a421_60f81db72a82row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 99.5%, transparent 0%);
#         }    #T_b399249a_b82a_11e7_a421_60f81db72a82row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 21.1%, transparent 0%);
#         }    #T_b399249a_b82a_11e7_a421_60f81db72a82row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0%);
#         }    #T_b399249a_b82a_11e7_a421_60f81db72a82row0_col5 {
#             width:  10em;
#              height:  80%;
#         }    #T_b399249a_b82a_11e7_a421_60f81db72a82row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 41.6%, transparent 0%);
#         }    #T_b399249a_b82a_11e7_a421_60f81db72a82row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 41.6%, transparent 0%);
#         }    #T_b399249a_b82a_11e7_a421_60f81db72a82row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 43.4%, transparent 0%);
#         }    #T_b399249a_b82a_11e7_a421_60f81db72a82row1_col3 {
#             width:  10em;
#              height:  80%;
#         }    #T_b399249a_b82a_11e7_a421_60f81db72a82row1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 99.9%, transparent 0%);
#         }    #T_b399249a_b82a_11e7_a421_60f81db72a82row1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#         }    #T_b399249a_b82a_11e7_a421_60f81db72a82row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#         }    #T_b399249a_b82a_11e7_a421_60f81db72a82row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#         }    #T_b399249a_b82a_11e7_a421_60f81db72a82row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#         }    #T_b399249a_b82a_11e7_a421_60f81db72a82row2_col3 {
#             width:  10em;
#              height:  80%;
#         }    #T_b399249a_b82a_11e7_a421_60f81db72a82row2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 8.3%, transparent 0%);
#         }    #T_b399249a_b82a_11e7_a421_60f81db72a82row2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 8.3%, transparent 0%);
#         }    #T_b399249a_b82a_11e7_a421_60f81db72a82row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 99.9%, transparent 0%);
#         }    #T_b399249a_b82a_11e7_a421_60f81db72a82row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 99.9%, transparent 0%);
#         }    #T_b399249a_b82a_11e7_a421_60f81db72a82row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#         }    #T_b399249a_b82a_11e7_a421_60f81db72a82row3_col3 {
#             width:  10em;
#              height:  80%;
#         }    #T_b399249a_b82a_11e7_a421_60f81db72a82row3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.6%, transparent 0%);
#         }    #T_b399249a_b82a_11e7_a421_60f81db72a82row3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.6%, transparent 0%);
#         }    #T_b399249a_b82a_11e7_a421_60f81db72a82row4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0%);
#         }    #T_b399249a_b82a_11e7_a421_60f81db72a82row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0%);
#         }    #T_b399249a_b82a_11e7_a421_60f81db72a82row4_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_b399249a_b82a_11e7_a421_60f81db72a82row4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 99.0%, transparent 0%);
#         }    #T_b399249a_b82a_11e7_a421_60f81db72a82row4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#         }    #T_b399249a_b82a_11e7_a421_60f81db72a82row4_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#         }    #T_b399249a_b82a_11e7_a421_60f81db72a82row5_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_b399249a_b82a_11e7_a421_60f81db72a82row5_col1 {
#             width:  10em;
#              height:  80%;
#         }    #T_b399249a_b82a_11e7_a421_60f81db72a82row5_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.4%, transparent 0%);
#         }    #T_b399249a_b82a_11e7_a421_60f81db72a82row5_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 64.5%, transparent 0%);
#         }    #T_b399249a_b82a_11e7_a421_60f81db72a82row5_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#         }    #T_b399249a_b82a_11e7_a421_60f81db72a82row5_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#         }    #T_b399249a_b82a_11e7_a421_60f81db72a82row6_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 99.5%, transparent 0%);
#         }    #T_b399249a_b82a_11e7_a421_60f81db72a82row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 99.5%, transparent 0%);
#         }    #T_b399249a_b82a_11e7_a421_60f81db72a82row6_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#         }    #T_b399249a_b82a_11e7_a421_60f81db72a82row6_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.0%, transparent 0%);
#         }    #T_b399249a_b82a_11e7_a421_60f81db72a82row6_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.1%, transparent 0%);
#         }    #T_b399249a_b82a_11e7_a421_60f81db72a82row6_col5 {
#             width:  10em;
#              height:  80%;
#         }    #T_b399249a_b82a_11e7_a421_60f81db72a82row7_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 9.8%, transparent 0%);
#         }    #T_b399249a_b82a_11e7_a421_60f81db72a82row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 9.8%, transpar
