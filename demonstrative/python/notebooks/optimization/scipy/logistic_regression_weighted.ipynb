# %% [markdown]
# # Weighted Logistic Regression

# %%
# %run -m ipy_startup
# %matplotlib inline
from py_utils import math

# %%
from scipy.stats import binom

# Generate random data to model
np.random.seed(1)
n, n_var = 1000, 25

X = np.random.randn(n, n_var)

b_act = np.random.randn(n_var)
b_int = -1.5
p = math.sigmoid(b_int + np.dot(X, b_act))

w = np.random.randint(1, 100, size=n)

y_success = binom.rvs(w, p)
y_sm = np.hstack([y_success[:,np.newaxis], (w - y_success)[:,np.newaxis]])
y = y_success / w

X.shape, y.shape
# Out:
# ((1000, 25), (1000,))

# %%
y_sm[:5], w[:5]
# Out:
# (array([[ 2, 56],
#         [ 1, 90],
#         [ 0, 68],
#         [34,  6],
#         [ 0, 76]]), array([58, 91, 68, 40, 76]))

# %%
pd.Series(w).describe()
# Out:
# count    1000.000000
# mean       47.685000
# std        28.382977
# min         1.000000
# 25%        23.000000
# 50%        46.000000
# 75%        73.000000
# max        99.000000
# dtype: float64

# %%
pd.Series(y).describe()
# Out:
# count    1000.000000
# mean        0.366408
# std         0.395953
# min         0.000000
# 25%         0.000000
# 50%         0.166687
# 75%         0.801087
# max         1.000000
# dtype: float64

# %%
from ml.scipy import optimize, models
param_names = ['X{}'.format(i) for i in range(n_var)]
constraints = optimize.ScipyConstraints()

model = (
    models.ScipyLogisticRegressionModelBuilder()
    .add_linear_params(param_names)
    .add_intercept()
    .build()
)

# %%
# %%time

import statsmodels.api as sm
from statsmodels.tools import add_constant

fit_w = w

# Weight scaling doesn't seem to matter except when it produces very small / large values
# - dividing by the mean seems to be a good practical method
fit_w_scaled = (fit_w / fit_w.mean())

est_wt = optimize.ScipyRegressor(model, analytical_gradients=True, monitor_gradient=True, raise_on_failure=False)
est_wt.fit(X, y, sample_weight=fit_w)

est_wtscaled = optimize.ScipyRegressor(model, analytical_gradients=True, monitor_gradient=True, raise_on_failure=False)
est_wtscaled.fit(X, y, sample_weight=fit_w_scaled)

est_wt1 = optimize.ScipyRegressor(model, analytical_gradients=True, monitor_gradient=True, raise_on_failure=False)
est_wt1.fit(X, y, sample_weight=np.ones(len(y)))

est_nowt = optimize.ScipyRegressor(model, analytical_gradients=True, monitor_gradient=True, raise_on_failure=False)
est_nowt.fit(X, y)

est_sm = sm.GLM(y, add_constant(X, prepend=True), family=sm.families.Binomial()).fit()
est_smwt = sm.GLM(y_sm, add_constant(X, prepend=True), family=sm.families.Binomial()).fit()
# Out:
# CPU times: user 1.05 s, sys: 61.5 ms, total: 1.12 s
# Wall time: 296 ms

# %%
print(est_wt.get_fit_summary())
# Out:
# Optimization converged successfully:
#
#     Success: True
#     Status Code: 0
#     Message: Optimization terminated successfully.
#     Number of iterations: 14
#     Number of function evaluations: 26
#     Objective Function Value: 12.356062052577487

# %%
from collections import OrderedDict

df_coef = pd.DataFrame({
    'est_sm': est_sm.params[1:],
    'est_smwt': est_smwt.params[1:],
    'est_wt': est_wt.inference()['linear'].values,
    'est_wtscaled': est_wtscaled.inference()['linear'].values,
    'est_ones': est_wt1.inference()['linear'].values,
    'est_nowt': est_nowt.inference()['linear'].values
}, index=est_nowt.inference()['linear'].index)

df_int = pd.DataFrame({
    'est_sm': est_sm.params[0],
    'est_smwt': est_smwt.params[0],
    'est_wt': est_wt.inference()['intercept'].values,
    'est_wtscaled': est_wtscaled.inference()['intercept'].values,
    'est_ones': est_wt1.inference()['intercept'].values,
    'est_nowt': est_nowt.inference()['intercept'].values
}, index=est_nowt.inference()['intercept'].index)

df = pd.concat([df_coef, df_int])
df[df.columns.sort_values()].style.bar(axis=1)
# Out:
# <style  type="text/css" >
#     #T_e878dc98_b834_11e7_ab11_60f81db72a82row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 96.1%, transparent 0%);
#         }    #T_e878dc98_b834_11e7_ab11_60f81db72a82row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 96.1%, transparent 0%);
#         }    #T_e878dc98_b834_11e7_ab11_60f81db72a82row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#         }    #T_e878dc98_b834_11e7_ab11_60f81db72a82row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.6%, transparent 0%);
#         }    #T_e878dc98_b834_11e7_ab11_60f81db72a82row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.9%, transparent 0%);
#         }    #T_e878dc98_b834_11e7_ab11_60f81db72a82row0_col5 {
#             width:  10em;
#              height:  80%;
#         }    #T_e878dc98_b834_11e7_ab11_60f81db72a82row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 99.5%, transparent 0%);
#         }    #T_e878dc98_b834_11e7_ab11_60f81db72a82row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 99.5%, transparent 0%);
#         }    #T_e878dc98_b834_11e7_ab11_60f81db72a82row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#         }    #T_e878dc98_b834_11e7_ab11_60f81db72a82row1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 4.2%, transparent 0%);
#         }    #T_e878dc98_b834_11e7_ab11_60f81db72a82row1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.1%, transparent 0%);
#         }    #T_e878dc98_b834_11e7_ab11_60f81db72a82row1_col5 {
#             width:  10em;
#              height:  80%;
#         }    #T_e878dc98_b834_11e7_ab11_60f81db72a82row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 88.7%, transparent 0%);
#         }    #T_e878dc98_b834_11e7_ab11_60f81db72a82row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 88.7%, transparent 0%);
#         }    #T_e878dc98_b834_11e7_ab11_60f81db72a82row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#         }    #T_e878dc98_b834_11e7_ab11_60f81db72a82row2_col3 {
#             width:  10em;
#              height:  80%;
#         }    #T_e878dc98_b834_11e7_ab11_60f81db72a82row2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.6%, transparent 0%);
#         }    #T_e878dc98_b834_11e7_ab11_60f81db72a82row2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.6%, transparent 0%);
#         }    #T_e878dc98_b834_11e7_ab11_60f81db72a82row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 99.4%, transparent 0%);
#         }    #T_e878dc98_b834_11e7_ab11_60f81db72a82row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 99.4%, transparent 0%);
#         }    #T_e878dc98_b834_11e7_ab11_60f81db72a82row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#         }    #T_e878dc98_b834_11e7_ab11_60f81db72a82row3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.5%, transparent 0%);
#         }    #T_e878dc98_b834_11e7_ab11_60f81db72a82row3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.4%, transparent 0%);
#         }    #T_e878dc98_b834_11e7_ab11_60f81db72a82row3_col5 {
#             width:  10em;
#              height:  80%;
#         }    #T_e878dc98_b834_11e7_ab11_60f81db72a82row4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 86.3%, transparent 0%);
#         }    #T_e878dc98_b834_11e7_ab11_60f81db72a82row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 86.3%, transparent 0%);
#         }    #T_e878dc98_b834_11e7_ab11_60f81db72a82row4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#         }    #T_e878dc98_b834_11e7_ab11_60f81db72a82row4_col3 {
#             width:  10em;
#              height:  80%;
#         }    #T_e878dc98_b834_11e7_ab11_60f81db72a82row4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.3%, transparent 0%);
#         }    #T_e878dc98_b834_11e7_ab11_60f81db72a82row4_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 9.9%, transparent 0%);
#         }    #T_e878dc98_b834_11e7_ab11_60f81db72a82row5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 6.9%, transparent 0%);
#         }    #T_e878dc98_b834_11e7_ab11_60f81db72a82row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 6.9%, transparent 0%);
#         }    #T_e878dc98_b834_11e7_ab11_60f81db72a82row5_col2 {
#             width:  10em;
#              height:  80%;
#         }    #T_e878dc98_b834_11e7_ab11_60f81db72a82row5_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 99.2%, transparent 0%);
#         }    #T_e878dc98_b834_11e7_ab11_60f81db72a82row5_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#         }    #T_e878dc98_b834_11e7_ab11_60f81db72a82row5_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 92.9%, transparent 0%);
#         }    #T_e878dc98_b834_11e7_ab11_60f81db72a82row6_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 95.4%, transparent 0%);
#         }    #T_e878dc98_b834_11e7_ab11_60f81db72a82row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 95.4%, transparent 0%);
#         }    #T_e878dc98_b834_11e7_ab11_60f81db72a82row6_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 0%);
#         }    #T_e878dc98_b834_11e7_ab11_60f81db72a82row6_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.4%, transparent 0%);
#         }    #T_e878dc98_b834_11e7_ab11_60f81db72a82row6_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.6%, transparent 0%);
#         }    #T_e878dc98_b834_11e7_ab11_60f81db72a82row6_col5 {
#             width:  10em;
#              height:  80%;
#         }    #T_e878dc98_b834_11e7_ab11_60f81db72a82row7_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_e878dc98_b834_11e7_ab11_60f81db72a82row7_col1 {
#             width:  10em;
#              height:  80%;
#         }    #T_e878dc98_b834_11e7_ab11_60f81db72a82row7_col2 {
#             w
