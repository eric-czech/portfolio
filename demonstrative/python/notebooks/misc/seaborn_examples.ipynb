# %%
# %run -m ipy_startup
# %run -m ipy_seaborn
# %matplotlib inline

# %%
df = sns.load_dataset("car_crashes")
df['speed'] = pd.cut(df['speeding'], bins=5)
df['prem'] = pd.cut(df['ins_premium'], bins=3)
df.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev           speed                 prem
# 0      145.08     AL  (6.387, 7.918]     (641.3, 861.813]
# 1      133.93     AK  (6.387, 7.918]  (861.813, 1081.667]
# 2      110.35     AZ  (6.387, 7.918]  (861.813, 1081.667]
# 3      142.39     AR  (3.324, 4.855]     (641.3, 861.813]
# 4      165.63     CA  (3.324, 4.855]  (861.813, 1081.667]

# %%
plt.figure(figsize=(12, 6))
with sns.axes_style('whitegrid'):
    sns.boxplot(x='speed', y='alcohol', hue='prem', data=df)

# %%
sns.clustermap(df.select_dtypes(include=[np.number]).corr())
